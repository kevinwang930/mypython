# %% [markdown]
# ### matplotlib data structure
# #### figure
# 1. figure._gridspecs stores all the gridspec

# %%
# pyplot functional method
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots()  # Create a figure containing a single axes.
print(fig._gridspecs)
ax.plot([1, 2, 3, 4], [1, 4, 2, 3])  # Plot some data on the axes.
plt.show()
# Out:
# [GridSpec(1, 1)]

# %%
# object oriented method, create figure, add axes, plot
from matplotlib import pyplot as plt
import numpy as np
import math
#figure 
fig=plt.figure(figsize=(6.4, 4.8),facecolor='skyblue', edgecolor='black',dpi=360)
ax = fig.add_axes([0,0,1,1], projection='rectilinear',xlabel='X-label',ylabel='Y-label',title='Creating new Figure & Axes')
x = np.arange(0, math.pi*2, 0.05)
y = np.sin(x)
ax.plot(x,y,color='black')
plt.show()

# %%
#date bar
import datetime

x = [datetime.datetime(2010, 12, 1, 10, 0),
    datetime.datetime(2010, 12, 1, 10, 0),
    datetime.datetime(2011, 5, 5, 9, 0)]
y = [4, 9, 2]

ax = plt.subplot(111)
ax.bar(x, y, width=10)
ax.xaxis_date()

plt.show()

# %%
N = 5
menMeans = (20, 35, 30, 35, 27)
menStd =   (2, 3, 4, 1, 2)

ind = np.arange(N)  # the x locations for the groups
width = 0.35       # the width of the bars

fig = plt.figure()
ax = fig.add_subplot(111)
rects1 = ax.bar(ind, menMeans, width, color='royalblue', yerr=menStd)

womenMeans = (25, 32, 34, 20, 25)
womenStd =   (3, 5, 2, 3, 3)
rects2 = ax.bar(ind+width, womenMeans, width, color='seagreen', yerr=womenStd)

# add some
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(ind + width / 2)
ax.set_xticklabels( ('G1', 'G2', 'G3', 'G4', 'G5') )

ax.legend( (rects1[0], rects2[0]), ('Men', 'Women') )

plt.show()

# %%
# panddas dataframe to handle same x coordinates
import pandas as pd
coins = ['penny', 'nickle', 'dime', 'quarter']
worth = [0.01, 0.05, 0.10, 0.25]
df = pd.DataFrame(worth, columns=['1x'], index=coins)
df['2x'] = df['1x'] * 2 
df['3x'] = df['1x'] * 3 
df['4x'] = df['1x'] * 4 
df['5x'] = df['1x'] * 5 
from matplotlib import ticker
import matplotlib.pyplot as plt

df.plot(kind='bar')

plt.ylabel('Monetary Value')
plt.gca().yaxis.set_major_formatter(ticker.FormatStrFormatter('$%.2f'))
plt.gca().xaxis.set_tick_params(rotation=0)

# %%
womenMeans = (25, 32, 34, 20, 25)
menMeans = (20, 35, 30, 35, 27)
indices = [5.5,6,7,8.5,8.9]
#Calculate optimal width
width = np.min(np.diff(indices))/3

fig = plt.figure()
ax = fig.add_subplot(111)
ax.bar(indices-width,womenMeans,width,color='b',label='-Ymin')
ax.bar(indices,menMeans,width,color='r',label='Ymax')
ax.set_xlabel('Test histogram')
plt.show()
